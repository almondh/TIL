# %% [markdown]
# # EDA 1
# 2019.12.01 ~
#
# 1. 고객성향별 클러스터링이 필요
# 2. 변수로 포함시킬 수 있는 외부데이터 - 날씨, 부동산 지수, 주가지수, 소득?, 황금연휴 등

# %% [markdown]
# ### import package

# %%
# -*- coding: cp949 -*-
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import timeit
import pandas_profiling as pp

from IPython.display import Image
# %matplotlib inline

# %%
# 코드 수행 시간 측정
start = timeit.default_timer()
stop = timeit.default_timer()
# print(stop - start)

# %%
Image("데이터 흐름도.jpg")

# %%
online = pd.read_csv('제6회 L.POINT Big Data Competition-분석용데이터-01.온라인 행동 정보.csv')
transaction = pd.read_csv('제6회 L.POINT Big Data Competition-분석용데이터-02.거래 정보.csv')
client = pd.read_csv('제6회 L.POINT Big Data Competition-분석용데이터-03.고객 Demographic 정보.csv')
products = pd.read_csv('제6회 L.POINT Big Data Competition-분석용데이터-04.상품분류 정보.csv')
# Out:
# C:\Users\huiyeon\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
online.shape
# Out:
# (3196362, 14)

# %%
online.head()
# Out:
#    clnt_id  sess_id  hit_seq  action_type biz_unit   sess_dt hit_tm  \
# 0     7809        1        8            5      A03  20190913  01:16
# 1     7809        1        4            2      A03  20190913  01:14
# 2     7809        1       11            5      A03  20190913  01:17
# 3     7809        1        1            2      A03  20190913  00:46
# 4     7809        1        9            5      A03  20190913  01:17
#
#    hit_pss_tm  trans_id sech_kwd  tot_pag_view_ct  tot_sess_hr_v trfc_src  \
# 0     2571103       NaN      NaN             34.0         2663.0   DIRECT
# 1     2485909       NaN      NaN             34.0         2663.0   DIRECT
# 2     2646597       NaN      NaN             34.0         2663.0   DIRECT
# 3      788304       NaN      NaN             34.0         2663.0   DIRECT
# 4     2617609       NaN      NaN             34.0         2663.0   DIRECT
#
#   dvc_ctg_nm
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
# Check NA
np.sum(pd.isnull(online))
# Out:
# clnt_id                  0
# sess_id                  0
# hit_seq                  0
# action_type              0
# biz_unit                 0
# sess_dt                  0
# hit_tm                   0
# hit_pss_tm               0
# trans_id           3139373
# sech_kwd           2544724
# tot_pag_view_ct       1428
# tot_sess_hr_v        57607
# trfc_src                 0
# dvc_ctg_nm         1782577
# dtype: int64

# %%
# id별 중복되는 session_id 수
online.groupby(['clnt_id'])['sess_id'].count()
# Out:
# clnt_id
# 1         10
# 2        249
# 3         10
# 4          2
# 5          1
#         ...
# 72425     25
# 72426      8
# 72427     26
# 72428      7
# 72429      2
# Name: sess_id, Length: 72399, dtype: int64

# %%
# trfc_src별 집계
online.groupby(['trfc_src']).count()['clnt_id']
# Out:
# trfc_src
# DIRECT      1715541
# PORTAL_1      40669
# PORTAL_2      30642
# PORTAL_3       9792
# PUSH         523300
# WEBSITE       49472
# unknown      826946
# Name: clnt_id, dtype: int64

# %%
# sech_kwd 개수
search_kwd = online[online['sech_kwd'].notnull()]['sech_kwd'].value_counts()
search_kwd = pd.DataFrame(search_kwd)

# %%
Top200_kwd = search_kwd[search_kwd['sech_kwd']>=200]  # 대부분 식품
Top200_kwd.reset_index(inplace=True)
Top200_kwd.columns = ['sech_kwd', 'cnt']
Top200_kwd
# Out:
#        sech_kwd   cnt
# 0            우유  8985
# 1            두부  5210
# 2            계란  5039
# 3            생수  4283
# 4            수박  2694
# ..          ...   ...
# 351          컵밥   203
# 352  생수500ml삼다수   203
# 353        제로콜라   202
# 354        요쿠르트   201
# 355         앞다리   201
#
# [356 rows x 2 columns]

# %%
search_kwd['sech_kwd'].sum() - Top200_kwd['cnt'].sum()
# 포함시키지 못한 검색 키워드 갯수 437345개 -> 사용불가?
# Out:
# 437345

# %%
# 행동유형 개수
# 0:검색
# 1:제품 목록
# 2:제품 세부정보 보기
# 3:장바구니 제품 추가
# 4:장바구니 제품 삭제
# 5:결제 시도
# 6:구매 완료
# 7:구매 환불
# 8:결제 옵션
online['action_type'].value_counts()  # 5 -> 6으로 가는 갯수 적음
# 750530 - 56249 = 694281
# Out:
# 5    750530
# 2    655266
# 0    651638
# 3    596765
# 1    307998
# 4    172240
# 6     56249
# 7      5676
# Name: action_type, dtype: int64

# %%
online.head()
# Out:
#    clnt_id  sess_id  hit_seq  action_type biz_unit   sess_dt hit_tm  \
# 0     7809        1        8            5      A03  20190913  01:16
# 1     7809        1        4            2      A03  20190913  01:14
# 2     7809        1       11            5      A03  20190913  01:17
# 3     7809        1        1            2      A03  20190913  00:46
# 4     7809        1        9            5      A03  20190913  01:17
#
#    hit_pss_tm  trans_id sech_kwd  tot_pag_view_ct  tot_sess_hr_v trfc_src  \
# 0     2571103       NaN      NaN             34.0         2663.0   DIRECT
# 1     2485909       NaN      NaN             34.0         2663.0   DIRECT
# 2     2646597       NaN      NaN             34.0         2663.0   DIRECT
# 3      788304       NaN      NaN             34.0         2663.0   DIRECT
# 4     2617609       NaN      NaN             34.0         2663.0   DIRECT
#
#   dvc_ctg_nm
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
online['action_type'].loc[1]
# Out:
# 2

# %% [raw]
# # Top200_kwd내에서 구매완료한(action_type=6) 갯수 알아보기
# # len(set(Top200_kwd['sech_kwd'])) : 356개로 중복된 값 없음
# kwd_type_6 = []  # 빈 list
#
# for i in online['sech_kwd']:
#     if i in set(Top200_kwd['sech_kwd']):
#         _ = online['action_type'].loc[i]
#         kwd_type_6.append(_)
#     else:
#         continue
#
# kwd_type_6

# %%
# 초 분으로 변환하기
online['hit_pss_min'] = round(online['hit_pss_tm']/60, 3)

# 분 시간으로 변환하기
online['hit_pss_hour'] = round(online['hit_pss_min']/60, 3)

# %%
# 조회경과시간(분)과 행동유형 plot
plt.rcParams['agg.path.chunksize'] = 20000
plt.plot('hit_pss_min', 'action_type', data=online,
         linestyle='none', marker='o', alpha=0.2)
plt.show()

# %%
# hit_pss_hour 분포 확인
plt.plot(online['hit_pss_hour'])

# %%
# 조회경과시간(시간)과 행동유형 plot
plt.plot('hit_pss_hour', 'action_type', data=online,
         linestyle='none', marker='o', alpha=0.2)
plt.show()

# %%
# hits 수 분포 살펴보기
plt.plot(online['hit_seq'])

# %%
# Hits 수와 action_type 살펴보기
online.groupby([ 'action_type'])['hit_seq'].mean()
# Out:
# action_type
# 0    14.807322
# 1    18.511809
# 2    13.108316
# 3    16.605632
# 4    22.806148
# 5    24.924777
# 6    21.518996
# 7    11.840204
# Name: hit_seq, dtype: float64

# %% [markdown]
# ### 논의해야 할 사항
# 1. 비식별고객은 제외하고 분석 할건지?
# 2. 검색어 sech_kwd 특수문자 제거하고 할건지?
# 3. 구매시간대 별 구매추천?
# 4. 고객 클러스터링 어떤 방식으로 진행할지?

# %%
# clnt_id 별 유입경로(trfc_src) 분포 알아보기
online.groupby(['clnt_id','trfc_src'])['trfc_src'].count()
# Out:
# clnt_id  trfc_src
# 1        unknown      10
# 2        DIRECT      249
# 3        unknown      10
# 4        unknown       2
# 5        PUSH          1
#                     ...
# 72425    unknown      25
# 72426    DIRECT        8
# 72427    unknown      26
# 72428    unknown       7
# 72429    DIRECT        2
# Name: trfc_src, Length: 79689, dtype: int64

# %%
client.head()
# Out:
#    clnt_id clnt_gender clnt_age
# 0        1     unknown  unknown
# 1        2           F       30
# 2        3     unknown  unknown
# 3        4     unknown  unknown
# 4        5     unknown  unknown

# %%
# online과 client 병합
df1 = pd.merge(client, online, on='clnt_id')
df1.head()
# Out:
#    clnt_id clnt_gender clnt_age  sess_id  hit_seq  action_type biz_unit  \
# 0        1     unknown  unknown        2        6            0      A01
# 1        1     unknown  unknown        1        3            0      A01
# 2        1     unknown  unknown        2        3            0      A01
# 3        1     unknown  unknown        2        1            0      A01
# 4        1     unknown  unknown        1        1            0      A01
#
#     sess_dt hit_tm  hit_pss_tm  trans_id sech_kwd  tot_pag_view_ct  \
# 0  20190922  14:12      178832       NaN  노스페이스초등             45.0
# 1  20190911  16:15       36140       NaN    과일바구니             14.0
# 2  20190922  14:10       70025       NaN    초등남아옷             45.0
# 3  20190922  14:09       41584       NaN   초등가을잠바             45.0
# 4  20190911  16:14       11880       NaN   과일선물세트             14.0
#
#    tot_sess_hr_v trfc_src  dvc_ctg_nm  hit_pss_min  hit_pss_hour
# 0          424.0  unknown  mobile_app     2980.533        49.676
# 1          124.0  unknown  mobile_app      602.333        10.039
# 2          424.0  unknown  mobile_app     1167.083        19.451
# 3          424.0  unknown  mobile_app      693.067        11.551
# 4          124.0  unknown  mobile_app      198.000         3.300

# %%
# 연령대별 세션id개수 살펴보기
plt.plot(df1.groupby(['clnt_age'])['sess_id'].count())

# %%
# 연령대별로 유입채널별, 세션id 개수 살펴보기
look1 = df1.pivot_table('sess_id', index='clnt_age', columns='trfc_src',
                        aggfunc='count')
plt.plot(look1)
plt.legend(look1.columns)

# %%
# 연령대별로 기기유형별 세션수 살펴보기
look2 = df1.pivot_table('sess_id', index='clnt_age', columns='dvc_ctg_nm',
                        aggfunc='count')
plt.plot(look2)
plt.legend(look2.columns)
# mobile_web > app > pc

# %%
online['biz_unit'].value_counts()
# Out:
# A03    2331437
# A02     668093
# A01     196832
# Name: biz_unit, dtype: int64

# %%
online['hit_seq'].value_counts()
# Out:
# 1      367149
# 2      246633
# 3      198580
# 4      167819
# 5      143873
#         ...
# 282         1
# 281         1
# 280         1
# 279         1
# 357         1
# Name: hit_seq, Length: 357, dtype: int64

# %%
# 조회 일련번호와 구매관계 살펴보기
online['trans_id'].isnull().value_counts()  
# 결측값 3139373, 값 보유 56989

# 구매이력 존재 = buyer 아니면 non_buyer
buyer = online[online['trans_id'].isnull()==False]
non_buyer = online[online['trans_id'].isnull()==True]

# %% [raw]
# 구매이력 존재하면 1, 0으로 레이블링 오류
# for i in range(len(online)):
#     if online['trans_id'][i]==np.nan:
#         online['buy_ex'] = 0
#     else :
#         online['buy_ex'] = 1

# %%
buyer.head()
# Out:
#      clnt_id  sess_id  hit_seq  action_type biz_unit   sess_dt hit_tm  \
# 105    28304        1       22            6      A03  20190716  11:41
# 206    24276       17       31            6      A03  20190806  16:52
# 246    24276        1       87            6      A03  20190702  21:42
# 708    47444       27       40            6      A03  20190930  19:56
# 710    47444       12       27            6      A03  20190818  12:05
#
#      hit_pss_tm  trans_id sech_kwd  tot_pag_view_ct  tot_sess_hr_v trfc_src  \
# 105     1212297   51903.0      NaN             56.0         1303.0     PUSH
# 206      983154   69420.0      NaN             26.0          998.0   DIRECT
# 246     8131793   40228.0      NaN             99.0         8132.0     PUSH
# 708     2612017  112652.0      NaN             70.0         2612.0   DIRECT
# 710     1146060   78445.0      NaN             47.0         1146.0   DIRECT
#
#      dvc_ctg_nm  hit_pss_min  hit_pss_hour
# 105  mobile_web    20204.950       336.749
# 206         NaN    16385.900       273.098
# 246         NaN   135529.883      2258.831
# 708          PC    43533.617       725.560
# 710          PC    19101.000       318.350

# %%
# 구매한 사람과 구매하지 않은 사람들의 조회이력 살펴보기
look3 = buyer.pivot_table('clnt_id', index='dvc_ctg_nm', columns='action_type',
                        aggfunc='count')
plt.plot(look3)
plt.legend(look3.columns)

# %%
look4 = non_buyer.pivot_table('clnt_id', index='dvc_ctg_nm', columns='action_type',
                            aggfunc='count')
plt.plot(look4)
plt.legend(look4.columns)
# 2 -> 3번으로 유도해야 구매건수 높아질 것으로 기대됨.

# %%
# buyer 유입채널 살펴보기
look5 = buyer.pivot_table('clnt_id', index='dvc_ctg_nm', columns='trfc_src',
                        aggfunc='count')
plt.plot(look5)
plt.legend(look5.columns)
# 대부분의 고객이 mobile_app을 로그인 하지 않은 채로 유입?

# %% [markdown]
# #### 온라인행동정보(online) + 거래 정보(transaction) merge

# %%
online_trans = pd.merge(online, transaction, on=['clnt_id', 'trans_id'])
online_trans.set_index(['clnt_id','trans_id'], inplace=True)
online_trans.sort_values(['clnt_id', 'trans_id', 'trans_seq'], inplace=True)
online_trans.head(10)
# Out:
#                   sess_id  hit_seq  action_type biz_unit_x   sess_dt hit_tm  \
# clnt_id trans_id
# 2       62037.0         1       37            6        A03  20190728  23:47
#         64691.0         8       68            6        A03  20190731  21:25
#         64691.0         8       68            6        A03  20190731  21:25
#         64691.0         8       68            6        A03  20190731  21:25
#         64691.0         8       68            6        A03  20190731  21:25
#         64691.0         8       68            6        A03  20190731  21:25
#         65505.0        10       16            6        A03  20190801  22:00
#         88495.0        19       17            6        A03  20190830  22:00
#         88495.0        19       17            6        A03  20190830  22:00
#         88495.0        19       17            6        A03  20190830  22:00
#
#                   hit_pss_tm sech_kwd  tot_pag_view_ct  tot_sess_hr_v  ...  \
# clnt_id trans_id                                                       ...
# 2       62037.0       791905      NaN             55.0          872.0  ...
#         64691.0      3251794      NaN             85.0         3256.0  ...
#         64691.0      3251794      NaN             85.0         3256.0  ...
#         64691.0      3251794      NaN             85.0         3256.0  ...
#         64691.0      3251794      NaN             85.0         3256.0  ...
#         64691.0      3251794      NaN             85.0         3256.0  ...
#         65505.0       306944      NaN             23.0          353.0  ...
#         88495.0      2227390      NaN             29.0         2253.0  ...
#         88495.0      2227390      NaN             29.0         2253.0  ...
#         88495.0      2227390      NaN             29.0         2253.0  ...
#
#                  dvc_ctg_nm hit_pss_min  hit_pss_hour  trans_seq  biz_unit_y  \
# clnt_id trans_id
# 2       62037.0         NaN   13198.417       219.974          1         A03
#         64691.0         NaN   54196.567       903.276          1         A03
#         64691.0         NaN   54196.567       903.276          2         A03
#         64691.0         NaN   54196.567       903.276          3         A03
#         64691.0         NaN   54196.567       903.276          4         A03
#         64691.0         NaN   54196.567       903.276          5         A03
#         65505.0         NaN    5115.733        85.262          1         A03
#         88495.0         NaN   37123.167       618.719          1         A03
#         88495.0         NaN   37123.167       618.719          2         A03
#         88495.0         NaN   37123.167       618.719          3         A03
#
#                   pd_c     de_dt  de_tm buy_am  buy_ct
# clnt_id trans_id
# 2       62037.0   0092  20190729  23:47  36000      20
#         64691.0   0186  20190731  21:25   3790       1
#         64691.0   0151  20190731  21:25   3990       1
#         64691.0   0351  20190731  21:25   4690       1
#         64691.0   0189  20190731  21:25   4290       1
#         64691.0   0092  20190731  21:25   1800       1
#         65505.0   0092  20190801  22:00   9000       5
#         88495.0   1395  20190830  22:00   3590       1
#         88495.0   1395  20190830  22:00   2850       1
#         88495.0   1395  20190830  22:00   5700       2
#
# [10 rows x 21 columns]

# %%
online_trans
# Out:
#                   sess_id  hit_seq  action_type biz_unit_x   sess_dt hit_tm  \
# clnt_id trans_id
# 2       62037.0         1       37            6        A03  20190728  23:47
#         64691.0         8       68            6        A03  20190731  21:25
#         64691.0         8       68            6        A03  20190731  21:25
#         64691.0         8       68            6        A03  20190731  21:25
#         64691.0         8       68            6        A03  20190731  21:25
# ...                   ...      ...          ...        ...       ...    ...
# 72400   65027.0         7        8            6        A02  20190731  09:46
# 72410   60926.0         3        8            6        A02  20190726  13:59
# 72423   102596.0        1        1            6        A01  20190917  11:48
# 72424   108506.0        2       52            6        A03  20190924  17:12
#         108506.0        2       52            6        A03  20190924  17:12
#
#                   hit_pss_tm sech_kwd  tot_pag_view_ct  tot_sess_hr_v  ...  \
# clnt_id trans_id                                                       ...
# 2       62037.0       791905      NaN             55.0          872.0  ...
#         64691.0      3251794      NaN             85.0         3256.0  ...
#         64691.0      3251794      NaN             85.0         3256.0  ...
#         64691.0      3251794      NaN             85.0         3256.0  ...
#         64691.0      3251794      NaN             85.0         3256.0  ...
# ...                      ...      ...              ...            ...  ...
# 72400   65027.0       103042      NaN              9.0          103.0  ...
# 72410   60926.0       437775      NaN             19.0          961.0  ...
# 72423   102596.0      116283      NaN             24.0          114.0  ...
# 72424   108506.0     2410463      NaN             82.0         2445.0  ...
#         108506.0     2410463      NaN             82.0         2445.0  ...
#
#                   dvc_ctg_nm hit_pss_min  hit_pss_hour  trans_seq  biz_unit_y  \
# clnt_id trans_id
# 2       62037.0          NaN   13198.417       219.974          1         A03
#         64691.0          NaN   54196.567       903.276          1         A03
#         64691.0          NaN   54196.567       903.276          2         A03
#         64691.0          NaN   54196.567       903.276          3         A03
#         64691.0          NaN   54196.567       903.276          4         A03
# ...                      ...         ...           ...        ...         ...
# 72400   65027.0   mobile_app    1717.367        28.623          1         A02
# 72410   60926.0           PC    7296.250       121.604          1         A02
# 72423   102596.0  mobile_app    1938.050        32.301          1         A01
# 72424   108506.0          PC   40174.383       669.573          1         A03
#         108506.0          PC   40174.383       669.573          2         A03
#
#                   pd_c     de_dt  de_tm  buy_am  buy_ct
# clnt_id trans_id
# 2       62037.0   0092  20190729  23:47   36000      20
#         64691.0   0186  20190731  21:25    3790       1
#         64691.0   0151  20190731  21:25    3990       1
#         64691.0   0351  20190731  21:25    4690       1
#         64691.0   0189  20190731  21:25    4290       1
# ...                ...       ...    ...     ...     ...
# 72400   65027.0   1064  20190731  09:46   78900       1
# 72410   60926.0   0350  20190726  13:59   14470       1
# 72423   102596.0  0169  20190917  11:48  479700       1
# 72424   108506.0  0968  20190924  17:12   14900       2
#         108506.0  0960  20190924  17:12   19900       1
#
# [127358 rows x 21 columns]

# %%
online_trans.columns
# Out:
# Index(['sess_id', 'hit_seq', 'action_type', 'biz_unit_x', 'sess_dt', 'hit_tm',
#        'hit_pss_tm', 'sech_kwd', 'tot_pag_view_ct', 'tot_sess_hr_v',
#        'trfc_src', 'dvc_ctg_nm', 'hit_pss_min', 'hit_pss_hour', 'trans_seq',
#        'biz_unit_y', 'pd_c', 'de_dt', 'de_tm', 'buy_am', 'buy_ct'],
#       dtype='object')

# %%
online_trans.drop(['biz_unit_y'], axis=1, inplace=True)
online_trans.rename(columns = {'biz_unit_x' : 'biz_unit'},
                   inplace=True)

# %%
# biz_unit : 온라인 및 오프라인 이용처를 구분하는 단위코드
online_trans['biz_unit'].value_counts()
# Out:
# A03    116173
# A02      9776
# A01      1409
# Name: biz_unit, dtype: int64

# %%
# trfc_src별, biz_unit의 sess_id 개수
online_trans.pivot_table('sess_id', index='trfc_src', columns='biz_unit',
                         aggfunc='count')
# 대부분이 A03, unknown은 거의 A02
# Out:
# biz_unit     A01     A02      A03
# trfc_src
# DIRECT     114.0     NaN  84805.0
# PORTAL_1    25.0     NaN    986.0
# PORTAL_2     1.0     NaN   1144.0
# PORTAL_3     NaN     NaN    236.0
# PUSH         NaN     NaN  27954.0
# WEBSITE     23.0     NaN   1048.0
# unknown   1246.0  9776.0      NaN

# %%
# 구매일자 별 구매금액총액 살펴보기
# 20190827, 20190917 ; 극도로 큰 값, 제외하고 사용해야할듯
# 혹은 간격을 변수로 넣어봐도 괜찮을 듯
pd.set_option('display.max_rows', 100)
online_trans.pivot_table('buy_am', index='de_dt',aggfunc='sum')
# Out:
#                 buy_am
# de_dt
# 20190701      15367820
# 20190702      20021012
# 20190703      19287291
# 20190704      27644488
# 20190705      18549168
# 20190706      16110806
# 20190707      38831736
# 20190708      22607289
# 20190709      15625265
# 20190710      21540256
# 20190711      16148019
# 20190712      20178690
# 20190713      21574865
# 20190714      16590708
# 20190715      22782056
# 20190716      14305801
# 20190717      21802207
# 20190718      20040803
# 20190719      24117406
# 20190720      31106563
# 20190721      17981355
# 20190722      28282966
# 20190723      13042982
# 20190724      28030415
# 20190725      19004170
# 20190726      23697753
# 20190727      16277849
# 20190728      13031447
# 20190729      16788479
# 20190730      14654740
# 20190731      23524448
# 20190801      24411285
# 20190802      12705838
# 20190803      15248282
# 20190804      10683895
# 20190805      18614478
# 20190806      21680218
# 20190807      22762518
# 20190808      26437407
# 20190809      15578172
# 20190810      21541614
# 20190811      11393414
# 20190812      17661785
# 20190813      34350399
# 20190814      20147235
# 20190815      22999571
# 20190816      18499738
# 20190817      13117352
# 20190818      18216333
# 20190819      21053517
# 20190820      15963846
# 20190821      20082195
# 20190822      16086909
# 20190823      23385883
# 20190824      15453261
# 20190825      22673027
# 20190826      28285608
# 20190827  100016913322
# 20190828      27363184
# 20190829      22223718
# 20190830      15757201
# 20190831      18121487
# 20190901      18350175
# 20190902      19477531
# 20190903      25166641
# 20190904      45265397
# 20190905      25754724
# 20190906      22249817
# 20190907      29083809
# 20190908      17959098
# 20190909       9588744
# 20190910      19493342
# 20190911      19032597
# 20190912      10593060
# 20190913      10508095
# 20190914      26020238
# 20190915      25346658
# 20190916      22649127
# 20190917  100024923738
# 20190918      30762964
# 20190919      30746119
# 20190920      17163974
# 20190921      27651701
# 20190922      23035178
# 20190923      10101406
# 20190924       7545897
# 20190925       9081078
# 20190926       8055506
# 20190927      12640325
# 20190928       5790382
# 20190929       7086935
# 20190930       8268836

# %%
# 구매시간대 분포 살펴보기
buy_time = online_trans.reset_index()
buy_time['de_tm'] = pd.to_datetime(buy_time['de_tm'], 
                                   format='%H:%M').dt.time
buy_time = buy_time['de_tm']
buy_time.value_counts().plot()
# 점심시간때 피크

# %% [raw]
# 시간별 범주화 고려

# %%
# 총 구매금액 = buy_am * buy_ct 변수 추가
online_trans['buy_sum'] = online_trans['buy_am'] * online_trans['buy_ct']
online_trans.pivot_table('buy_sum', index='de_dt',aggfunc='sum')
# 20190813, 20190826, 20190827, 20190917 : ????
# Out:
#                buy_sum
# de_dt
# 20190701      18456440
# 20190702      24515702
# 20190703      26439947
# 20190704      33223030
# 20190705      28187288
# 20190706      20770086
# 20190707      42150988
# 20190708      31782401
# 20190709      27310251
# 20190710      27295046
# 20190711      21664555
# 20190712      25241008
# 20190713      24471331
# 20190714      18966774
# 20190715      27359698
# 20190716      18577159
# 20190717      26852651
# 20190718      26618737
# 20190719      34949530
# 20190720      34611347
# 20190721      21061475
# 20190722      36973442
# 20190723      18043334
# 20190724      33736907
# 20190725      23257236
# 20190726      29915551
# 20190727      19645991
# 20190728      20562709
# 20190729      21285419
# 20190730      20503030
# 20190731      31012686
# 20190801      28501551
# 20190802      17768276
# 20190803      20245000
# 20190804      14302233
# 20190805      24265820
# 20190806      28561776
# 20190807      30263696
# 20190808      34622711
# 20190809      22478568
# 20190810      25768594
# 20190811      14196424
# 20190812      23026953
# 20190813    5278686375
# 20190814      25838145
# 20190815      29339941
# 20190816      24910878
# 20190817      16021042
# 20190818      21107601
# 20190819      26958309
# 20190820      20091708
# 20190821      26331641
# 20190822      24190225
# 20190823      29494475
# 20190824      17449873
# 20190825      25299227
# 20190826    5274652208
# 20190827  400020288543
# 20190828      32576148
# 20190829      27702724
# 20190830      21265219
# 20190831      38381287
# 20190901      20523537
# 20190902      27258213
# 20190903      31778929
# 20190904      51448343
# 20190905      36227494
# 20190906      31997903
# 20190907      35476601
# 20190908      24094888
# 20190909      19131706
# 20190910      30435586
# 20190911      26933547
# 20190912      15898920
# 20190913      11047655
# 20190914      28204576
# 20190915      28313958
# 20190916      26686215
# 20190917  100048084660
# 20190918      40449056
# 20190919      37769643
# 20190920      24497734
# 20190921      32917109
# 20190922      25968256
# 20190923      16381312
# 20190924      13583879
# 20190925      17311680
# 20190926      14353140
# 20190927      21236269
# 20190928       9837358
# 20190929      11738159
# 20190930      13212218

# %%
# 극값을 보이던 20190813, 20190826, 20190827, 20190917의 
# 구매시각 확인해보기 : 6381 건의 거래
heavy_buying = online_trans[(online_trans.de_dt==20190813)|(online_trans.de_dt==20190826)|\
                            (online_trans.de_dt==20190827)|(online_trans.de_dt==20190917)]
heavy_buying = heavy_buying.reset_index()
heavy_buying['de_tm'] = pd.to_datetime(heavy_buying['de_tm'], 
                                       format='%H:%M').dt.time
heavy_buying = heavy_buying['de_tm']
heavy_buying.value_counts().plot()
# 9시~12시 피크? 출근 후 점심시간 전까지

# %%
heavy_buying.value_counts()
# Out:
# 11:12:00    61
# 12:13:00    45
# 10:20:00    42
# 10:53:00    41
# 15:04:00    39
#             ..
# 16:26:00     1
# 00:38:00     1
# 09:35:00     1
# 07:47:00     1
# 03:07:00     1
# Name: de_tm, Length: 670, dtype: int64

# %% [markdown]
# ### 전체 merge
# 온라인행동정보(online) + 고객정보(client) + 거래정보(transaction) + 상품(products)
#
# *상품(products)넘버가 없는 unknown존재하여 products에 행 추가*

# %%
# merge 위해서 unknown값 추가
products.loc[1667] = ['unknown', 'unknown', 'unknown', 'unknown']

# %%
# merge -> 전처리
online_client = pd.merge(online, client, on=['clnt_id'])
online_client_transaction = pd.merge(online_client, transaction, on=['clnt_id', 'trans_id'])
online_client_transaction['pd_c'] = pd.to_numeric(online_client_transaction['pd_c'],
                                                  errors = 'coerce') 
All_data = pd.merge(online_client_transaction, products, on=['pd_c'], how='left')

All_data.sort_values(['clnt_id','sess_id','trans_seq'], inplace=True)
All_data.reset_index(inplace=True)
All_data.drop(['index'], axis=1, inplace=True)
All_data.drop(['biz_unit_y'], axis=1, inplace=True)
All_data.rename(columns = {'biz_unit_x' : 'biz_unit'}, inplace=True)

All_data.head()
# Out:
#    clnt_id  sess_id  hit_seq  action_type biz_unit   sess_dt hit_tm  \
# 0        2        1       37            6      A03  20190728  23:47
# 1        2        8       68            6      A03  20190731  21:25
# 2        2        8       68            6      A03  20190731  21:25
# 3        2        8       68            6      A03  20190731  21:25
# 4        2        8       68            6      A03  20190731  21:25
#
#    hit_pss_tm  trans_id sech_kwd  ...  clnt_age  trans_seq pd_c     de_dt  \
# 0      791905   62037.0      NaN  ...        30          1   92  20190729
# 1     3251794   64691.0      NaN  ...        30          1  186  20190731
# 2     3251794   64691.0      NaN  ...        30          2  151  20190731
# 3     3251794   64691.0      NaN  ...        30          3  351  20190731
# 4     3251794   64691.0      NaN  ...        30          4  189  20190731
#
#    de_tm  buy_am buy_ct               clac_nm1                    clac_nm2  \
# 0  23:47   36000     20              Beverages               Coffee Drinks
# 1  21:25    3790      1          Chilled Foods  Fish Cakes and Crab Sticks
# 2  21:25    3990      1  Canned / Jarred Foods   Canned Agricultural Foods
# 3  21:25    4690      1         Dairy Products    Processed Dairy Products
# 4  21:25    4290      1          Chilled Foods  Fish Cakes and Crab Sticks
#
#                    clac_nm3
# 0             Coffee Drinks
# 1               Crab Sticks
# 2    Canned Vegetable Foods
# 3  Cream and Condensed milk
# 4                Fried Tofu
#
# [5 rows x 27 columns]

# %%
# 127358 
np.sum(pd.isnull(All_data))
# Out:
# clnt_id                 0
# sess_id                 0
# hit_seq                 0
# action_type             0
# biz_unit                0
# sess_dt                 0
# hit_tm                  0
# hit_pss_tm              0
# trans_id                0
# sech_kwd           127358
# tot_pag_view_ct         0
# tot_sess_hr_v         300
# trfc_src                0
# dvc_ctg_nm          91475
# hit_pss_min             0
# hit_pss_hour            0
# clnt_gender             0
# clnt_age                0
# trans_seq               0
# pd_c                 4263
# de_dt                   0
# de_tm                   0
# buy_am                  0
# buy_ct                  0
# clac_nm1             4263
# clac_nm2             4263
# clac_nm3             4268
# dtype: int64

# %%
All_data.clac_nm1.value_counts()
# Out:
# Vegetables                                   15274
# Substitute Foods                             11457
# Meats                                        11096
# Snack Foods                                  10856
# Chilled Foods                                10579
# Dairy Products                               10262
# Frozen Foods                                  8563
# Beverages                                     7769
# Fruits                                        7509
# Spices / Seasonings                           5017
# Detergents / Hygiene Goods                    3488
# Women's Clothing                              2748
# Canned / Jarred Foods                         2645
# Dried Sea Foods                               1731
# Personal Care                                 1729
# Fashion Accessories                           1320
# Sea Foods                                     1236
# Grains                                        1044
# Sport Fashion                                  984
# Coffee / Tea                                   961
# Cosmetics / Beauty Care                        910
# Cooked Foods                                   837
# Health Foods                                   683
# Kitchenware                                    629
# Underwear / Socks and Hosiery / Homewear       611
# Bedding / Handicraft                           365
# Birth Supplies / Baby Products                 313
# Others (Non-Products)                          285
# Kids' Clothing                                 258
# Home / Kitchen Appliances                      222
# Tableware / Cooking Utensils                   159
# Cleaning / Laundry / Bathroom Accessories      157
# Men's Clothing                                 157
# Gardening / Pets                               132
# Outdoor / Leisure Activities                   102
# Furniture                                      102
# Heating / Cooling Electronics                   94
# Seasonal Sports                                 93
# Toy                                             76
# Health Care                                     72
# Cell Phones / Accessories                       65
# Baby Foods                                      60
# Home Decor / Lighting                           57
# Stationary / Office Supplies                    54
# Refrigerators and Washing Machines              48
# Computers                                       46
# Tools / Safety Supplies                         38
# Ball Game / Field Sports                        37
# Other Products                                  33
# Travel / Leisure Services                       30
# Video / Audio System Electronics                23
# Books / Records / Instruments                   21
# Health / Fitness Training                       19
# Gift Certificates / Cards                       17
# Liquors / Alcoholic Beverages                   15
# Automotive Products                              7
# Name: clac_nm1, dtype: int64

# %%
# 업종 별 구매시각 확인해보기
look6 = All_data.pivot_table('trans_seq', index='de_tm', columns='clac_nm1',
                        aggfunc='count')
look6.loc['Total'] = look6.sum()
look6.sort_values(by=['Total'], axis=1, ascending=False, inplace=True)
look6
# Out:
# clac_nm1  Vegetables  Substitute Foods    Meats  Snack Foods  Chilled Foods  \
# de_tm
# 00:00            8.0               2.0      2.0          NaN            NaN
# 00:01            3.0               NaN      1.0          1.0            2.0
# 00:02            NaN               NaN      NaN          NaN            1.0
# 00:03            4.0               4.0      5.0          4.0            3.0
# 00:04           18.0               5.0     11.0          3.0            6.0
# ...              ...               ...      ...          ...            ...
# 23:56           24.0              32.0     12.0         36.0           28.0
# 23:57           32.0              15.0      9.0          7.0           11.0
# 23:58           22.0              16.0     27.0         35.0           18.0
# 23:59           38.0              24.0     16.0         22.0           41.0
# Total        15274.0           11457.0  11096.0      10856.0        10579.0
#
# clac_nm1  Dairy Products  Frozen Foods  Beverages  Fruits  \
# de_tm
# 00:00                NaN           1.0        2.0     1.0
# 00:01                1.0           4.0        1.0     1.0
# 00:02                NaN           NaN        NaN     NaN
# 00:03                7.0           4.0        6.0     2.0
# 00:04                4.0           2.0        5.0     3.0
# ...                  ...           ...        ...     ...
# 23:56               24.0          18.0       18.0     5.0
# 23:57               17.0          14.0        5.0    12.0
# 23:58               28.0          23.0       18.0    23.0
# 23:59               32.0          21.0       20.0    15.0
# Total            10262.0        8563.0     7769.0  7509.0
#
# clac_nm1  Spices / Seasonings  ...  Tools / Safety Supplies  \
# de_tm                          ...
# 00:00                     NaN  ...                      NaN
# 00:01                     NaN  ...                      NaN
# 00:02                     NaN  ...                      NaN
# 00:03                     2.0  ...                      NaN
# 00:04                     2.0  ...                      NaN
# ...                       ...  ...                      ...
# 23:56                     5.0  ...                      NaN
# 23:57                     3.0  ...                      NaN
# 23:58                     9.0  ...                      NaN
# 23:59                     9.0  ...                      NaN
# Total                  5017.0  ...                     38.0
#
# clac_nm1  Ball Game / Field Sports  Other Products  Travel / Leisure Services  \
# de_tm
# 00:00                          NaN             NaN                        NaN
# 00:01                          NaN             NaN                        NaN
# 00:02                          NaN             NaN                        NaN
# 00:03                          NaN             NaN                        NaN
# 00:04                          NaN             NaN                        NaN
# ...                            ...             ...                        ...
# 23:56                          NaN             NaN                        NaN
# 23:57                          NaN             NaN                        NaN
# 23:58                          NaN             NaN                        NaN
# 23:59                          NaN             NaN                        NaN
# Total                         37.0            33.0                       30.0
#
# clac_nm1  Video / Audio System Electronics  Books / Records / Instruments  \
# de_tm
# 00:00                                  NaN                            NaN
# 00:01                                  NaN                            NaN
# 00:02                                  NaN                            NaN
# 00:03                                  NaN                            NaN
# 00:04                                  NaN                            NaN
# ...                                    ...                            ...
# 23:56                                  NaN                            NaN
# 23:57                                  NaN                            NaN
# 23:58                                  NaN                            NaN
# 23:59                                  NaN                            NaN
# Total                                 23.0                           21.0
#
# clac_nm1  Health / Fitness Training  Gift Certificates / Cards  \
# de_tm
# 00:00                           NaN                        NaN
# 00:01                           NaN                        NaN
# 00:02                           NaN                        NaN
# 00:03                           NaN                        NaN
# 00:04                           NaN                        NaN
# ...                             ...                        ...
# 23:56                           NaN                        NaN
# 23:57                           NaN                        NaN
# 23:58                           NaN                        NaN
# 23:59                           NaN                        NaN
# Total                          19.0                       17.0
#
# clac_nm1  Liquors / Alcoholic Beverages  Automotive Products
# de_tm
# 00:00                               NaN                  NaN
# 00:01                               NaN                  NaN
# 00:02                               NaN                  NaN
# 00:03                               NaN                  NaN
# 00:04                               NaN                  NaN
# ...                                 ...                  ...
# 23:56                               NaN                  NaN
# 23:57                               NaN                  NaN
# 23:58                               NaN                  NaN
# 23:59                               NaN                  NaN
# Total                              15.0                  7.0
#
# [1398 rows x 56 columns]

# %%
# 상위 3개 항목 구매시간 비교
look6.drop('Total')['Vegetables'].plot()
look6.drop('Total')['Substitute Foods'].plot()
look6.drop('Total')['Meats'].plot()
plt.legend(look6.columns[:3])
# 항목별 구매시각에 큰 차이는 없어보임

# %%
# 하위 3개 항목 구매시간 비교
look6.drop('Total')['Gift Certificates / Cards'].plot(lw=7)
look6.drop('Total')['Liquors / Alcoholic Beverages'].plot(lw=7)
look6.drop('Total')['Automotive Products'].plot(lw=7)
plt.legend(look6.columns[-3:])
# 그래프상에 나타나지 않음
